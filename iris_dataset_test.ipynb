# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("iris.csv")

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df_grouped = df.groupby("variety")

# %%
for group in df_grouped:
    print(len(group[1].columns))
    np_group = group[1].to_numpy()
    print(np_group[0][4])
# Out:
# 5
# Setosa
# 5
# Versicolor
# 5
# Virginica

# %%
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
print("Hello")
# Out:
# Hello

# %%
len(df_grouped)
# Out:
# 3

# %%
import os

# %%
os.system("wilkslambda.py")
# Out:
# 1

# %%
import wilkslambda

# %%
sample_size = 50

# %%
wilks_lambda_value = wilkslambda.wilks_lambda_analysis(df_grouped, sample_size)

# %%
wilks_lambda_value
# Out:
# np.float64(0.023438630650878423)
